# %% [markdown]
# # Normalize

# %% [markdown]
# This script does very simple normalization of the data from CollegeData. It ultimately saves two CSV files:
#
# * `collegedata_unnormalized.csv` This is the merge of the three tables without any normalization
# * `collegedata_normalized.csv` The merge of the three tables with some normalization

# %%
import TIdatabase as ti
# %matplotlib inline 
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
import statsmodels.api as sm
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
from matplotlib import rcParams
pd.options.display.max_columns = 100

# %%
#see database.ipynb for more information
colleges = ti.College()

# %%
students = ti.Student()
students.read("scrape/collegedata/collegedata_students.csv")

# %%
applForm = ti.ApplForm()
applForm.read("scrape/collegedata/collegedata_applications.csv")

# %%
# Merge all three tables into a single dataframe
applications = pd.merge(students.df, applForm.df)
applications = pd.merge(applications, colleges.df)
applications.head(10)
# Out:
#     studentID  classrank  admissionstest  AP  averageAP  SATsubject   GPA  \
# 0  S50C3UECT8        NaN            2290   7   5.000000           3  3.80
# 1  GBWZQQRBEV        NaN            2260   7   4.714286           2  3.94
# 2  MXXLWO1HQ2        NaN            2180   0        NaN           3  3.92
# 3  5KSL7C8SLZ        NaN            2370   7   4.857143           4  3.86
# 4  RQWLNGGZ49        NaN            2200   1   4.000000           2  3.95
# 5  A7WDLWR2VM        NaN            2200   0        NaN           2  4.00
# 6  CECT9K8GDY        NaN            2270   0        NaN           2  3.90
# 7  9PM1B51CXG        NaN            1700   3   3.666667           2  3.70
# 8  G14LB2SV7O        NaN            2140   7   4.000000           0  3.94
# 9  PSBRN09QGH        NaN            2120   4   4.250000           2  4.00
#
#    GPA_w                 program  schooltype  intendedgradyear  \
# 0   4.34  Biomedical engineering          -1              2017
# 1   4.47                Classics          -1              2013
# 2   3.92      Biological Science           1              2016
# 3   4.17                 Physics           1              2015
# 4    NaN                     NaN           1              2011
# 5    NaN       Political Science           1              2016
# 6   4.40        Computer Science          -1              2017
# 7   4.20                     NaN          -1              2016
# 8   3.94                Business          -1              2011
# 9   5.00        Computer Science          -1              2016
#
#                                              addInfo  canAfford  female  \
# 0  Basketball outside of school violin cancer awa...          0       1
# 1  Brain Bowl President and Captain 3 years Mu Al...          0      -1
# 2  Ballet 4 Years Bhangra 6 Years Volunteer WildC...          0       1
# 3                                                NaN          0      -1
# 4  4 yrs Varsity Wrestling 2x Team Captain Academ...          0      -1
# 5                                                NaN          0       1
# 6                                                NaN          0      -1
# 7                                                NaN          0      -1
# 8                                                NaN          0      -1
# 9                                                NaN          0      -1
#
#    MinorityGender  MinorityRace  international  firstinfamily  sports  artist  \
# 0              -1            -1             -1            NaN      -1     NaN
# 1              -1            -1             -1            NaN      -1     NaN
# 2              -1             1             -1            NaN      -1     NaN
# 3              -1            -1             -1            NaN      -1     NaN
# 4              -1            -1             -1            NaN      -1     NaN
# 5              -1            -1              1            NaN      -1     NaN
# 6              -1            -1             -1            NaN      -1     NaN
# 7              -1             1             -1            NaN      -1     NaN
# 8              -1            -1             -1            NaN      -1     NaN
# 9              -1            -1             -1            NaN      -1     NaN
#
#    workexp collegeID  earlyAppl  visited  alumni  outofstate  acceptStatus  \
# 0      NaN      Rice         -1      NaN      -1          -1             1
# 1      NaN      Rice         -1      NaN      -1           1             1
# 2      NaN      Rice         -1      NaN      -1           1            -1
# 3      NaN      Rice         -1      NaN      -1           1            -1
# 4      NaN      Rice          1      NaN      -1           1             1
# 5      NaN      Rice         -1      NaN      -1           1             0
# 6      NaN      Rice         -1      NaN      -1           1            -1
# 7      NaN      Rice         -1      NaN      -1           1            -1
# 8      NaN      Rice         -1      NaN      -1          -1            -1
# 9      NaN      Rice          1      NaN      -1           1             1
#
#    acceptProb  name  acceptrate  size  public  finAidPct  instatePct
# 0         NaN  Rice       0.151  6621      -1          0           0
# 1         NaN  Rice       0.151  6621      -1          0           0
# 2         NaN  Rice       0.151  6621      -1          0           0
# 3         NaN  Rice       0.151  6621      -1          0           0
# 4         NaN  Rice       0.151  6621      -1          0           0
# 5         NaN  Rice       0.151  6621      -1          0           0
# 6         NaN  Rice       0.151  6621      -1          0           0
# 7         NaN  Rice       0.151  6621      -1          0           0
# 8         NaN  Rice       0.151  6621      -1          0           0
# 9         NaN  Rice       0.151  6621      -1          0           0

# %%
applications.to_csv("collegedata_unnormalized.csv")

# %%
print applications.columns

cols_to_norm = ['admissionstest', 'averageAP', 'GPA', 'GPA_w']
indicator_cols = ["schooltype","canAfford","female","MinorityGender","MinorityRace","international","firstinfamily","sports","artist","workexp","earlyAppl","visited","alumni","outofstate","acceptStatus","public"]

meandict = {}
stddict={}

for col in cols_to_norm:
    meandict[col] = np.mean(applications[col])
    stddict[col] = np.std(applications[col])
print meandict
print stddict
# Out:
# Index([u'studentID', u'classrank', u'admissionstest', u'AP', u'averageAP',
#        u'SATsubject', u'GPA', u'GPA_w', u'program', u'schooltype',
#        u'intendedgradyear', u'addInfo', u'canAfford', u'female',
#        u'MinorityGender', u'MinorityRace', u'international', u'firstinfamily',
#        u'sports', u'artist', u'workexp', u'collegeID', u'earlyAppl',
#        u'visited', u'alumni', u'outofstate', u'acceptStatus', u'acceptProb',
#        u'name', u'acceptrate', u'size', u'public', u'finAidPct',
#        u'instatePct'],
#       dtype='object')
# {'averageAP': 4.249003971472805, 'admissionstest': 2143.606872126258, 'GPA': 3.838660991674003, 'GPA_w': 4.317342819580864}
# {'averageAP': 0.7032275578051195, 'admissionstest': 174.5042600523976, 'GPA': 0.20553017343332664, 'GPA_w': 0.38354906227331065}

# %%
#http://stackoverflow.com/questions/10373247/how-do-i-write-a-python-dictionary-to-a-csv-file
import csv

with open("normalize_means.csv","wb") as f:
    w = csv.DictWriter(f,meandict.keys())
    w.writeheader()
    w.writerow(meandict)
with open("normalize_stds.csv","wb") as f:
    w = csv.DictWriter(f,stddict.keys())
    w.writeheader()
    w.writerow(stddict)

# %%
# Now normalize specific columns
# Ref: http://stackoverflow.com/questions/28576540/how-can-i-normalize-the-data-in-a-range-of-columns-in-my-pandas-dataframe

def clean_indicator(col):
    yvec=[]
    for i in range(len(col)):
        if col[i]==0:
            y=np.nan
        elif col[i]==-1:
            y=0
        else:
            y=col[i]
        yvec.append(y)
    return yvec
def normalise(col):
    return (col-np.mean(col)) / np.std(col)
applications[cols_to_norm] = applications[cols_to_norm].apply(normalise)
applications[indicator_cols] = applications[indicator_cols].apply(clean_indicator)
print applications.shape
applications.head(10)
# Out:
# (16094, 34)
#     studentID  classrank  admissionstest  AP  averageAP  SATsubject       GPA  \
# 0  S50C3UECT8        NaN        0.838909   7   1.067927           3 -0.188104
# 1  GBWZQQRBEV        NaN        0.666993   7   0.661638           2  0.493061
# 2  MXXLWO1HQ2        NaN        0.208552   0        NaN           3  0.395752
# 3  5KSL7C8SLZ        NaN        1.297350   7   0.864783           4  0.103824
# 4  RQWLNGGZ49        NaN        0.323162   1  -0.354087           2  0.541716
# 5  A7WDLWR2VM        NaN        0.323162   0        NaN           2  0.784989
# 6  CECT9K8GDY        NaN        0.724298   0        NaN           2  0.298443
# 7  9PM1B51CXG        NaN       -2.542098   3  -0.828092           2 -0.674650
# 8  G14LB2SV7O        NaN       -0.020669   7  -0.354087           0  0.493061
# 9  PSBRN09QGH        NaN       -0.135280   4   0.001416           2  0.784989
#
#       GPA_w                 program  schooltype  intendedgradyear  \
# 0  0.059072  Biomedical engineering           0              2017
# 1  0.398012                Classics           0              2013
# 2 -1.035963      Biological Science           1              2016
# 3 -0.384156                 Physics           1              2015
# 4       NaN                     NaN           1              2011
# 5       NaN       Political Science           1              2016
# 6  0.215506        Computer Science           0              2017
# 7 -0.305940                     NaN           0              2016
# 8 -0.983819                Business           0              2011
# 9  1.779843        Computer Science           0              2016
#
#                                              addInfo  canAfford  female  \
# 0  Basketball outside of school violin cancer awa...        NaN       1
# 1  Brain Bowl President and Captain 3 years Mu Al...        NaN       0
# 2  Ballet 4 Years Bhangra 6 Years Volunteer WildC...        NaN       1
# 3                                                NaN        NaN       0
# 4  4 yrs Varsity Wrestling 2x Team Captain Academ...        NaN       0
# 5                                                NaN        NaN       1
# 6                                                NaN        NaN       0
# 7                                                NaN        NaN       0
# 8                                                NaN        NaN       0
# 9                                                NaN        NaN       0
#
#    MinorityGender  MinorityRace  international  firstinfamily  sports  artist  \
# 0               0             0              0            NaN       0     NaN
# 1               0             0              0            NaN       0     NaN
# 2               0             1              0            NaN       0     NaN
# 3               0             0              0            NaN       0     NaN
# 4               0             0              0            NaN       0     NaN
# 5               0             0              1            NaN       0     NaN
# 6               0             0              0            NaN       0     NaN
# 7               0             1              0            NaN       0     NaN
# 8               0             0              0            NaN       0     NaN
# 9               0             0              0            NaN       0     NaN
#
#    workexp collegeID  earlyAppl  visited  alumni  outofstate  acceptStatus  \
# 0      NaN      Rice          0      NaN       0           0             1
# 1      NaN      Rice          0      NaN       0           1             1
# 2      NaN      Rice          0      NaN       0           1             0
# 3      NaN      Rice          0      NaN       0           1             0
# 4      NaN      Rice          1      NaN       0           1             1
# 5      NaN      Rice          0      NaN       0           1           NaN
# 6      NaN      Rice          0      NaN       0           1             0
# 7      NaN      Rice          0      NaN       0           1             0
# 8      NaN      Rice          0      NaN       0           0             0
# 9      NaN      Rice          1      NaN       0           1             1
#
#    acceptProb  name  acceptrate  size  public  finAidPct  instatePct
# 0         NaN  Rice       0.151  6621       0          0           0
# 1         NaN  Rice       0.151  6621       0          0           0
# 2         NaN  Rice       0.151  6621       0          0           0
# 3         NaN  Rice       0.151  6621       0          0           0
# 4         NaN  Rice       0.151  6621       0          0           0
# 5         NaN  Rice       0.151  6621       0          0           0
# 6         NaN  Rice       0.151  6621       0          0           0
# 7         NaN  Rice       0.151  6621       0          0           0
# 8         NaN  Rice       0.151  6621       0          0           0
# 9         NaN  Rice       0.151  6621       0          0           0

# %%
applications.to_csv("collegedata_normalized.csv")
